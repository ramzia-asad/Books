# %%
# !pip install tensorflow --upgrade
import tensorflow as tf
tf.__version__
# Out:
# Requirement already up-to-date: tensorflow in /usr/local/lib/python3.7/dist-packages (2.4.1)
# ...
# '2.4.1'

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.datasets import models, layers, optimizers
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-456c22343852> in <module>()
#       1 from tensorflow.keras.datasets import imdb
# ----> 2 from tensorflow.keras.datasets import models, layers, optimizers
#       3 import numpy as np
#
# ImportError: cannot import name 'models' from 'tensorflow.keras.datasets' (/usr/local/lib/python3.7/dist-packages/tensorflow/keras/datasets/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from tensorflow.keras.datasets import models, layers, optimizers
